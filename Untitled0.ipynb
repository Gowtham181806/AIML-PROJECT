# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowtham181806/AIML-PROJECT/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
X = df[['Mileage','Age(yrs)']]

# %%
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 9     30000         3
# 10    77000         5
# 3     22500         2
# 7     42500         2
# 11    21500         2
# 4     46000         4
# 2     57000         5
# 1     35000         3
# 5     15000         3
# 8     49000         4

# %%
 from sklearn.model_selection import train_test_split
 X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 6     97000         5
# 8     49000         4
# 2     57000         5
# 12    96000         4
# 5     15000         3
# 10    77000         5
# 1     35000         3
# 0     69000         6
# 4     46000         4
# 9     30000         3

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 7     42500         2
# 11    21500         2

# %%
y_train
# Out:
# 6     26100
# 8     31500
# 2     26100
# 12    31800
# 5     34000
# 10    24100
# 1     34000
# 0     18000
# 4     31500
# 9     33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
clf.score(X_test, y_test)
# Out:
# -1.681649268449072
